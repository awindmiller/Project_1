# %% [markdown]
# ## Graphing and Plotting

# %% [markdown]
# **Import Dependencies**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from citipy import citipy
from datetime import datetime
import csv

# %% [markdown]
# **Import CSV file**

# %%
final_df_csv = "totest1.csv"
final_df = pd.read_csv(final_df_csv, low_memory=False)
final_df.drop(['Unnamed: 0','Balls'],axis=1,inplace=True)

# %% [markdown]
# **Setting Jupyter Column and DataFrame Display**

# %%
pd.set_option("display.max_columns",30)
final_df.rename(columns={'Velocity2.1':'Velocity'}, inplace=True)
final_df.head()
# Out:
#    BreakAngle  Result  EndVelocity  Velocity  Nasty         TypeofPitch  \
# 0       -25.0  Strike         84.1      92.9   55.0   Fourseam Fastball
# 1       -40.7  Strike         84.1      92.8   31.0   Fourseam Fastball
# 2       -43.7  Strike         85.2      94.1   49.0   Fourseam Fastball
# 3        -1.3    Ball         84.0      91.0   41.0   Fourseam Fastball
# 4        18.4    Ball         69.6      75.4   18.0           Curveball
#
#   Strike/Ball/X    Result2 L/RPitcher L/RBatter            AwayTeam  \
# 0        Strike  Groundout          L         L  St Louis Cardinals
# 1        Strike  Groundout          L         L  St Louis Cardinals
# 2        Strike  Groundout          L         L  St Louis Cardinals
# 3          Ball  Groundout          L         L  St Louis Cardinals
# 4          Ball  Groundout          L         L  St Louis Cardinals
#
#          Date      HomeTeam StartTime        Stadium Batter1    Batter2  \
# 0  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 1  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 2  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 3  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 4  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
#
#   Pitcher1 Pitcher2  Temp Conditions  Wind_Speed(MPH)
# 0      Jon   Lester    44      clear                7
# 1      Jon   Lester    44      clear                7
# 2      Jon   Lester    44      clear                7
# 3      Jon   Lester    44      clear                7
# 4      Jon   Lester    44      clear                7

# %% [markdown]
# **Baseball Stadiums and Summary Statistics DataFrame**

# %%
stadium_summary = final_df.groupby(['Stadium']).mean().reset_index()

# %%
stadium_summary.dropna(subset=['BreakAngle'], inplace = True)

# %%
stadium_summary.sort_values(['Velocity'],ascending=False,inplace=True)

# %% [markdown]
# *Top 5 Stadiums by Velocity*

# %%
stadium_summary.head()
# Out:
#                      Stadium  BreakAngle  EndVelocity   Velocity      Nasty  \
# 26                  PNC Park    6.176552    82.416013  89.354096  44.629682
# 6                 Citi Field   10.152064    81.644156  89.098970  44.456457
# 15  Great American Ball Park    7.108426    82.069230  88.939824  44.481510
# 9                Coors Field    0.256149    82.641305  88.915854  43.938058
# 22            Nationals Park    8.083450    81.753138  88.868912  44.375457
#
#          Temp  Wind_Speed(MPH)
# 26  73.296265         8.099304
# 6   73.000601        10.708545
# 15  75.218376         7.528466
# 9   74.325776         6.363465
# 22  77.570662         6.845642

# %% [markdown]
# *Bottom 5 Stadiums by Velocity*

# %%
stadium_summary.tail()
# Out:
#                      Stadium  BreakAngle  EndVelocity   Velocity      Nasty  \
# 13          Fort Bragg Field   -4.467606    81.798592  87.679577  44.232394
# 2   Angel Stadium of Anaheim    5.402618    80.376960  87.582636  45.068171
# 21          Minute Maid Park    1.495942    80.287191  87.490020  44.334753
# 3              BB&T Ballpark    4.990458    79.875954  87.395420  42.156489
# 23             O.co Coliseum    1.371137    80.852032  87.035457  45.667081
#
#          Temp  Wind_Speed(MPH)
# 13  81.000000         5.000000
# 2   74.075713         7.052295
# 21  73.715714         1.486885
# 3   74.000000         5.000000
# 23  65.174504        11.126538

# %%
x= stadium_summary['Wind_Speed(MPH)']
y= stadium_summary['Velocity']
z= stadium_summary['BreakAngle']
w= stadium_summary['Nasty']
v= stadium_summary['Temp']

plt.scatter(v,y)
plt.ylim(86.5,90)
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.ylabel('Velocity in MPH', fontsize = 15) #for y label
plt.xlabel('Temperature in F', fontsize = 15) #for x label
plt.title('Temperature v Velocity by Stadium',fontsize =17)
plt.tight_layout()
plt.savefig("Temperature v Velocity (Stadium Averages).png")
plt.show()

# %% [markdown]
# *Using Seaborn Plots to Determine Correlation - Very Helpful Utility*

# %%
import seaborn as sns

# %%
sns.pairplot(stadium_summary)
plt.savefig("Correlation Plot Stadium Summary.png")
plt.show()

# %% [markdown]
# *Splitting Columns*

# %%
new = final_df["Date"].str.split("-", n=2,expand=True)
final_df['year']=new[0]
final_df['month']=new[1]
final_df.head()
# Out:
#    BreakAngle  Result  EndVelocity  Velocity  Nasty         TypeofPitch  \
# 0       -25.0  Strike         84.1      92.9   55.0   Fourseam Fastball
# 1       -40.7  Strike         84.1      92.8   31.0   Fourseam Fastball
# 2       -43.7  Strike         85.2      94.1   49.0   Fourseam Fastball
# 3        -1.3    Ball         84.0      91.0   41.0   Fourseam Fastball
# 4        18.4    Ball         69.6      75.4   18.0           Curveball
#
#   Strike/Ball/X    Result2 L/RPitcher L/RBatter            AwayTeam  \
# 0        Strike  Groundout          L         L  St Louis Cardinals
# 1        Strike  Groundout          L         L  St Louis Cardinals
# 2        Strike  Groundout          L         L  St Louis Cardinals
# 3          Ball  Groundout          L         L  St Louis Cardinals
# 4          Ball  Groundout          L         L  St Louis Cardinals
#
#          Date      HomeTeam StartTime        Stadium Batter1    Batter2  \
# 0  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 1  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 2  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 3  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
# 4  2015-04-05  Chicago Cubs   7:17 PM  Wrigley Field    Matt  Carpenter
#
#   Pitcher1 Pitcher2  Temp Conditions  Wind_Speed(MPH)  year month
# 0      Jon   Lester    44      clear                7  2015    04
# 1      Jon   Lester    44      clear                7  2015    04
# 2      Jon   Lester    44      clear                7  2015    04
# 3      Jon   Lester    44      clear                7  2015    04
# 4      Jon   Lester    44      clear                7  2015    04

# %% [markdown]
# *Utilizing Groupby*

# %%
month_pitch = final_df.groupby(['TypeofPitch','month'])['Velocity','Temp'].mean()
month_pitch.head(10)
# Out:
#                     Velocity       Temp
# TypeofPitch month
#  Changeup   03     84.222834  63.506318
#             04     83.705496  63.395240
#             05     83.762150  69.644799
#             06     83.871210  75.920810
#             07     83.923849  79.298195
#             08     83.815853  78.429137
#             09     84.012091  74.879854
#             10     83.368973  67.280060
#  Curveball  03     78.122912  65.033860
#             04     77.468976  63.109025

# %% [markdown]
# **Determining Seasonal Trends**

# %%
Cutter_df = month_pitch.loc[[' Cutter']].reset_index()
x=['Mar','Apr','May','Jun','Jul','Aug','Sep','Oct']
a=Cutter_df['Velocity']
Fourseam_df = month_pitch.loc[[' Fourseam Fastball']].reset_index()
b=Fourseam_df['Velocity']
Twoseam_df = month_pitch.loc[[' Twoseam Fastball']].reset_index()
c=Twoseam_df['Velocity']
Sinker_df = month_pitch.loc[[' Sinker']].reset_index()
d=Sinker_df['Velocity']

plt.title('Fastball Velocity by Month',fontsize=14,fontweight=3)
plt.xlabel("Month",fontsize=12)
plt.ylabel("Velocity in MPH",fontsize=12)
plt.ylim(87,94)
plt.plot(x,a, marker='o',color='blue',label='Cutter')
plt.plot(x,b, marker='o',color='green',label='Fourseam')
plt.plot(x,c, marker='o',color='yellow',label='Twoseam')
plt.plot(x,d, marker='o',color='orange',label='Sinker')
plt.tight_layout()
plt.legend(loc=4,title="Fastballs:",fontsize=9,bbox_to_anchor=(1.3,0.6))
plt.savefig("Fastball Velocity by Month.png")
plt.show()

# %% [markdown]
# **Interesting Discovery**

# %% [markdown]
# Finding correlation between Break Angle and Velocity clearly showed that, in general pitches thrown with more velocity had a positve break angle.  Off-speed pitches generally had a very negative break angle.

# %%
pitch_break = final_df.groupby(['TypeofPitch'])['BreakAngle'].mean().reset_index().sort_values('BreakAngle')
misc = final_df.groupby(['TypeofPitch'])['Velocity'].mean().reset_index()
pitch_break.drop([14,16,15,8,5],inplace=True)
pitch_break = pd.merge(pitch_break,misc,how='inner',on='TypeofPitch')
pitch_break
# Out:
#            TypeofPitch  BreakAngle   Velocity
# 0            Screwball  -21.950442  78.464602
# 1        Knuckle curve   -6.058107  80.468974
# 2            Curveball   -5.291870  77.868495
# 3               Eephus   -5.257914  66.990675
# 4               Cutter   -4.800487  88.240273
# 5               Slider   -4.655388  84.364766
# 6           Knuckeball    0.405648  75.813863
# 7             Changeup    6.458895  83.845158
# 8               Sinker    9.021240  91.424604
# 9    Fourseam Fastball   11.083392  92.861865
# 10            Splitter   13.432275  84.619579
# 11    Twoseam Fastball   15.314990  92.198641

# %%
pitch_break.to_csv("Pitch Break.csv")

# %%
pitches=list(pitch_break['TypeofPitch'].unique())
Velocity = pitch_break['Velocity']
Break = pitch_break['BreakAngle']
label = pitch_break['TypeofPitch']
for item in range(len(pitches)):
    plt.scatter(Velocity[item],Break[item],label=label[item],s=(Velocity[item]-66)*8)
plt.legend(title = 'Pitches:',bbox_to_anchor=(1.01,1.03))
plt.title("Velocity and Break Angles by Pitch Type",fontsize=14)
plt.xlabel("Velocity in MPH",fontsize=12)
plt.ylabel("Break Angle", fontsize =12)
plt.xlim(65,100)
plt.tight_layout()
plt.savefig("Velocity and Break Angle by Pitch.png")
plt.show()

# %%
pitch_result = final_df.groupby(['month','TypeofPitch'])['Strike/Ball/X'].count().reset_index()
pitch_result = pitch_result[pitch_result['TypeofPitch']!=' Intentional ball']
pitch_result = pitch_result[pitch_result['TypeofPitch']!=' Unknown']
pitch_result = pitch_result[pitch_result['TypeofPitch']!='FA']
pitch_result = pitch_result[pitch_result['TypeofPitch']!='AB']
pitch_result = pitch_result[pitch_result['TypeofPitch']!=' Pitchout']
pitch_result.head()
# Out:
#   month         TypeofPitch  Strike/Ball/X
# 0    03            Changeup           1108
# 1    03           Curveball            886
# 2    03              Cutter            579
# 3    03              Eephus              1
# 4    03   Fourseam Fastball           4151

# %% [markdown]
# *Pitches by Month were Pretty Evenly Distributed*

# %%
pitch_result_sum = pitch_result.groupby(['month']).sum().reset_index()
pitch_result_sum
# Out:
#   month  Strike/Ball/X
# 0    03          11684
# 1    04         418059
# 2    05         491972
# 3    06         474206
# 4    07         442394
# 5    08         493728
# 6    09         483308
# 7    10          29912

# %% [markdown]
# **Determining Variability of Pitch Usage**

# %%
pitch_result = pd.merge(pitch_result,pitch_result_sum,how='inner',on='month')
pitch_result['Pitch_Ratio']=pitch_result['Strike/Ball/X_x']/pitch_result['Strike/Ball/X_y']*100

# %%
pitch_result = pitch_result[['month','TypeofPitch','Pitch_Ratio']]

# %%
pitch_result.groupby(['month','TypeofPitch']).sum().unstack().plot(kind='bar',stacked=True)
plt.legend(title = 'Type of Pitch:',bbox_to_anchor=(1.01,1.03), ncol=1, fontsize=10)
plt.title('Proportion of Pitches Thrown by Month',fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Pitch Comp by Type and Month', fontsize=12)
Month=['Mar','Apr','May','Jun','Jul','Aug','Sep','Oct']
plt.xticks(np.arange(8),('Mar','Apr','May','Jun','Jul','Aug','Sep','Oct'),rotation=90)

plt.tight_layout()
plt.savefig("Pitch Comp by Type and Month.png")
plt.show()

# %%
proportion_df = pitch_result.reset_index()
proportion_df= proportion_df.groupby(['TypeofPitch','month'])['Pitch_Ratio'].sum()

# %%
otherdf = proportion_df.reset_index()
proportion_df1 = list(otherdf['TypeofPitch'].unique())

# %%
Eephus = proportion_df.loc[[' Eephus']].reset_index()
Eephus
# Out:
#   TypeofPitch month  Pitch_Ratio
# 0      Eephus    03     0.008559
# 1      Eephus    04     0.028704
# 2      Eephus    05     0.026018
# 3      Eephus    06     0.045128
# 4      Eephus    07     0.028255
# 5      Eephus    08     0.023900
# 6      Eephus    09     0.022553

# %%
proportion_df1
date_list=['Mar','Apr','May','Jun','Jul','Aug','Sep','Oct']

Changeup = proportion_df.loc[[' Changeup']].reset_index()
Curveball = proportion_df.loc[[' Curveball']].reset_index()
Cutter = proportion_df.loc[[' Cutter']].reset_index()
Eephus = proportion_df.loc[[ ' Eephus']].reset_index()
Fourseam = proportion_df.loc[[' Fourseam Fastball']].reset_index()
Knuckle = proportion_df.loc[[' Knuckle curve']].reset_index()
Sinker = proportion_df.loc[[' Sinker']].reset_index()
Slider = proportion_df.loc[[ ' Slider']].reset_index()
Splitter = proportion_df.loc[[' Splitter']].reset_index()
Twoseam = proportion_df.loc[[ ' Twoseam Fastball']].reset_index()
Knuckleball = proportion_df.loc[[ ' Knuckeball']].reset_index()
Screwball = proportion_df.loc[[' Screwball']].reset_index()

a=Changeup['Pitch_Ratio']
b=Curveball['Pitch_Ratio']
c=Cutter['Pitch_Ratio']
e=Fourseam['Pitch_Ratio']
f=Knuckle['Pitch_Ratio']
g=Sinker['Pitch_Ratio']
h=Slider['Pitch_Ratio']
i=Splitter['Pitch_Ratio']
j=Twoseam['Pitch_Ratio']

plt.title('Pitch Usage by Month and Pitch Type',fontsize=14,fontweight=3)
plt.xlabel("Month",fontsize=12)
plt.ylabel("Pitch Usage %",fontsize=12)
plt.ylim(0,40)
plt.plot(date_list,a, marker='o',color=np.random.random(3),label=proportion_df1[0])
plt.plot(date_list,b, marker='o',color=np.random.random(3),label=proportion_df1[1])
plt.plot(date_list,c, marker='o',color=np.random.random(3),label=proportion_df1[2])
plt.plot(date_list,e, marker='o',color=np.random.random(3),label=proportion_df1[4])
plt.plot(date_list,f, marker='o',color=np.random.random(3),label=proportion_df1[5])
plt.plot(date_list,g, marker='o',color=np.random.random(3),label=proportion_df1[6])
plt.plot(date_list,h, marker='o',color=np.random.random(3),label=proportion_df1[7])
plt.plot(date_list,i, marker='o',color=np.random.random(3),label=proportion_df1[8])
plt.plot(date_list,j, marker='o',color=np.random.random(3),label=proportion_df1[9])

plt.tight_layout()
plt.legend(loc=4,title="Pitch Type:",fontsize=12,bbox_to_anchor=(1.5,0.1))
plt.savefig("Pitch Usage by Type and Month.png")
plt.show()

# %% [markdown]
# Excluded from the plot due to lack of usage
#     #d=Eephus['Pitch_Ratio']
#     #k=Knuckleball['Pitch_Ratio']
#     #l=Screwball['Pitch_Ratio']
#     #plt.plot(date_list,d, marker='o',color=np.random.random(3),label=proportion_df1[3])
#     #plt.plot(date_list,k, marker='o',color=np.random.random(3),label=proportion_df1[10])
#     #plt.plot(date_list,l, marker='o',color=np.random.random(3),label=proportion_df1[11])

# %%
yankee_both = final_df.loc[(final_df['AwayTeam'] == 'New York Yankees') | (final_df['HomeTeam'] == 'New York Yankees')]
yankee_both.shape
# Out:
# (194736, 24)

# %%
chapman_df['BreakAngle'].astype(str).astype(float)
chapman_df = chapman_df.loc[chapman_df['BreakAngle'] < 0]
chapman_fast = chapman_df.loc[(chapman_df['TypeofPitch'].str.contains('Fourseam Fastball')==True) | (chapman_df['TypeofPitch'].str.contains('Sinker')==True)]
chapman_fast.shape
# Out:
# (1674, 24)

# %%
chapman_fast.describe()
# Out:
#         BreakAngle  EndVelocity     Velocity        Nasty         Temp  \
# count  1674.000000  1674.000000  1674.000000  1674.000000  1674.000000
# mean    -33.755257    90.866786    99.622461    44.387097    73.146356
# std      16.627374     1.851513     1.759951    14.403110    10.956828
# min     -90.000000    80.600000    94.700000    12.000000    42.000000
# 25%     -46.100000    89.700000    98.400000    34.000000    68.000000
# 50%     -33.400000    90.900000    99.600000    44.000000    75.000000
# 75%     -20.700000    92.100000   100.800000    54.000000    81.000000
# max      -0.100000    96.000000   105.000000    85.000000    93.000000
#
#        Wind_Speed(MPH)
# count      1674.000000
# mean          8.557945
# std           4.414891
# min           0.000000
# 25%           6.000000
# 50%           8.000000
# 75%          11.000000
# max          25.000000

# %%
chapman_fast.to_csv("chapman.csv")

# %%
dfy = chapman_fast.groupby('Temp').agg({'Velocity': [np.sum, np.mean, np.std]})
dfy.tail()
# Out:
#      Velocity
#           sum        mean       std
# Temp
# 88     1774.3   98.572222  1.022572
# 90      705.1  100.728571  1.273727
# 91     1117.3  101.572727  1.272864
# 92     1542.3  102.820000  1.455629
# 93     2638.5  101.480769  1.509707

# %%
dfy.head()
# Out:
#      Velocity
#           sum       mean       std
# Temp
# 42     1281.2  98.553846  1.404526
# 43     2789.7  99.632143  1.010337
# 45     1867.3  98.278947  1.492045
# 53     5514.5  98.473214  1.126619
# 55     1180.6  98.383333  1.397292

# %%
sns.regplot(chapman_fast['Temp'],chapman_fast['Velocity'])

# %%
chapman_fast.corr()
# Out:
#                  BreakAngle  EndVelocity  Velocity     Nasty      Temp  \
# BreakAngle         1.000000    -0.355305 -0.407519 -0.062024  0.006666
# EndVelocity       -0.355305     1.000000  0.878387  0.030309  0.336922
# Velocity          -0.407519     0.878387  1.000000  0.037241  0.230701
# Nasty             -0.062024     0.030309  0.037241  1.000000 -0.013824
# Temp               0.006666     0.336922  0.230701 -0.013824  1.000000
# Wind_Speed(MPH)    0.036112    -0.028400 -0.034485 -0.001763 -0.185049
#
#                  Wind_Speed(MPH)
# BreakAngle              0.036112
# EndVelocity            -0.028400
# Velocity               -0.034485
# Nasty                  -0.001763
# Temp                   -0.185049
# Wind_Speed(MPH)         1.000000
